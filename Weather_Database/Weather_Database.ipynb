# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Part 1. Retrieve Weather Data

# %%
# Create a set of 2,000 random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Iterate through the zipped lat_lngs tuple and find the nearest city.

from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
# We have initialized the counters at 1 because we want the first iteration of the logging for each recorded response and
# the set to start at 1.
record_count = 1
set_count = 1

# Loop through all the cities in the list. 
# We create the for loop with the enumerate() method and reference the index and the city in the list
# as the URL will need the city name, not the index.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    # We are removing the blank spaces in the city name and concatenating the city name with, city.replace(" ","+").
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    # The "pass" statement is a general purpose statement to handle all errors encountered and to allow the program to continue.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | manicore
# Processing Record 5 of Set 1 | safaga
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | taltal
# Processing Record 9 of Set 1 | pringsewu
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | itoman
# Processing Record 12 of Set 1 | burica
# City not found. Skipping...
# Processing Record 13 of Set 1 | stokmarknes
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | ingham
# Processing Record 16 of Set 1 | lorengau
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | poum
# Processing Record 19 of Set 1 | kapchorwa
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | darhan
# Processing Record 23 of Set 1 | mon
# Processing Record 24 of Set 1 | mehamn
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | abu dhabi
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | malakal
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | doha
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | kununurra
# Processing Record 40 of Set 1 | lotofaga
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | peabiru
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | tilichiki
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | mao
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | baherden
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | awbari
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | necochea
# Processing Record 14 of Set 2 | margate
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | namibe
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | san francisco
# Processing Record 21 of Set 2 | yinchuan
# Processing Record 22 of Set 2 | waitati
# Processing Record 23 of Set 2 | amapala
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | pokhara
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | hassleholm
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | chifeng
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | yumen
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | lipin bor
# Processing Record 42 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 2 | goderich
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | olafsvik
# Processing Record 47 of Set 2 | lauro muller
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | motygino
# Processing Record 50 of Set 2 | beringovskiy
# Processing Record 1 of Set 3 | komsomolskiy
# Processing Record 2 of Set 3 | fare
# Processing Record 3 of Set 3 | sechura
# Processing Record 4 of Set 3 | anadyr
# Processing Record 5 of Set 3 | hermosillo
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | preobrazheniye
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | velizh
# Processing Record 12 of Set 3 | kargasok
# Processing Record 13 of Set 3 | ararat
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | auki
# Processing Record 16 of Set 3 | churapcha
# Processing Record 17 of Set 3 | huarmey
# Processing Record 18 of Set 3 | aksarka
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | srednekolymsk
# Processing Record 21 of Set 3 | cumra
# Processing Record 22 of Set 3 | shimoda
# Processing Record 23 of Set 3 | morros
# Processing Record 24 of Set 3 | hambantota
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | didwana
# Processing Record 27 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 3 | tuatapere
# Processing Record 29 of Set 3 | visakhapatnam
# Processing Record 30 of Set 3 | rabat
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | bella union
# Processing Record 33 of Set 3 | malinovoye ozero
# Processing Record 34 of Set 3 | sistranda
# Processing Record 35 of Set 3 | maldonado
# Processing Record 36 of Set 3 | husavik
# Processing Record 37 of Set 3 | sangar
# Processing Record 38 of Set 3 | canberra
# Processing Record 39 of Set 3 | vanimo
# Processing Record 40 of Set 3 | tulsipur
# Processing Record 41 of Set 3 | hermanus
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | erdemli
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | brownfield
# Processing Record 46 of Set 3 | ulagan
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | mersing
# Processing Record 50 of Set 3 | tooele
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | chapais
# Processing Record 3 of Set 4 | sal rei
# Processing Record 4 of Set 4 | troitskoye
# Processing Record 5 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | chapleau
# Processing Record 8 of Set 4 | veraval
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | pevek
# Processing Record 11 of Set 4 | thurso
# Processing Record 12 of Set 4 | ponta do sol
# Processing Record 13 of Set 4 | matay
# Processing Record 14 of Set 4 | mayo
# Processing Record 15 of Set 4 | uchiza
# Processing Record 16 of Set 4 | ambilobe
# Processing Record 17 of Set 4 | saumur
# Processing Record 18 of Set 4 | atlantic city
# Processing Record 19 of Set 4 | kaeo
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | benguela
# Processing Record 22 of Set 4 | achinsk
# Processing Record 23 of Set 4 | boyolangu
# Processing Record 24 of Set 4 | vao
# Processing Record 25 of Set 4 | baghdad
# Processing Record 26 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | tongliao
# Processing Record 29 of Set 4 | bereda
# Processing Record 30 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 4 | saldanha
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | avera
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | zlobin
# Processing Record 36 of Set 4 | verkhnyaya sysert
# Processing Record 37 of Set 4 | henties bay
# Processing Record 38 of Set 4 | havelock
# Processing Record 39 of Set 4 | piacabucu
# Processing Record 40 of Set 4 | ponta delgada
# Processing Record 41 of Set 4 | cedar city
# Processing Record 42 of Set 4 | hlatikulu
# Processing Record 43 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 44 of Set 4 | mayuge
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | new norfolk
# Processing Record 47 of Set 4 | faanui
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | nikki
# Processing Record 50 of Set 4 | banda aceh
# Processing Record 1 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 5 | launceston
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | kruisfontein
# Processing Record 5 of Set 5 | bambanglipuro
# Processing Record 6 of Set 5 | tiksi
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | boueni
# Processing Record 9 of Set 5 | mana
# Processing Record 10 of Set 5 | ambon
# Processing Record 11 of Set 5 | saint george
# Processing Record 12 of Set 5 | mahebourg
# Processing Record 13 of Set 5 | najran
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 5 | port blair
# Processing Record 16 of Set 5 | san cristobal
# Processing Record 17 of Set 5 | oktyabrskiy
# Processing Record 18 of Set 5 | farah
# Processing Record 19 of Set 5 | baruun-urt
# Processing Record 20 of Set 5 | ondangwa
# Processing Record 21 of Set 5 | lasa
# Processing Record 22 of Set 5 | road town
# Processing Record 23 of Set 5 | sol-iletsk
# Processing Record 24 of Set 5 | ganzhou
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | vegreville
# Processing Record 27 of Set 5 | sampit
# Processing Record 28 of Set 5 | mazamari
# Processing Record 29 of Set 5 | havre-saint-pierre
# Processing Record 30 of Set 5 | inhambane
# Processing Record 31 of Set 5 | north bend
# Processing Record 32 of Set 5 | gamba
# Processing Record 33 of Set 5 | yulara
# Processing Record 34 of Set 5 | mitsamiouli
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | upernavik
# Processing Record 37 of Set 5 | hervey bay
# Processing Record 38 of Set 5 | zhuhai
# Processing Record 39 of Set 5 | sao jose da coroa grande
# Processing Record 40 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 5 | vangaindrano
# Processing Record 42 of Set 5 | sisimiut
# Processing Record 43 of Set 5 | tessalit
# Processing Record 44 of Set 5 | obo
# Processing Record 45 of Set 5 | vryburg
# Processing Record 46 of Set 5 | sur
# Processing Record 47 of Set 5 | norman wells
# Processing Record 48 of Set 5 | quatre cocos
# Processing Record 49 of Set 5 | urengoy
# Processing Record 50 of Set 5 | nemuro
# Processing Record 1 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 6 | sao joao da barra
# Processing Record 3 of Set 6 | mount isa
# Processing Record 4 of Set 6 | nikolayevsk-na-amure
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | saint-leu
# Processing Record 7 of Set 6 | zhireken
# Processing Record 8 of Set 6 | osinki
# Processing Record 9 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 6 | palu
# Processing Record 11 of Set 6 | paita
# Processing Record 12 of Set 6 | port lincoln
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | oyama
# Processing Record 15 of Set 6 | vestmannaeyjar
# Processing Record 16 of Set 6 | oxbow
# Processing Record 17 of Set 6 | pizhanka
# Processing Record 18 of Set 6 | burnie
# Processing Record 19 of Set 6 | zyryanka
# Processing Record 20 of Set 6 | nuuk
# Processing Record 21 of Set 6 | berbera
# Processing Record 22 of Set 6 | puerto baquerizo moreno
# Processing Record 23 of Set 6 | muyezerskiy
# Processing Record 24 of Set 6 | magadan
# Processing Record 25 of Set 6 | karpathos
# Processing Record 26 of Set 6 | juba
# Processing Record 27 of Set 6 | faya
# Processing Record 28 of Set 6 | cururupu
# Processing Record 29 of Set 6 | winchester
# Processing Record 30 of Set 6 | laiyang
# Processing Record 31 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 6 | saint-augustin
# Processing Record 33 of Set 6 | surin
# Processing Record 34 of Set 6 | mecca
# Processing Record 35 of Set 6 | gharghoda
# Processing Record 36 of Set 6 | bay city
# Processing Record 37 of Set 6 | nanakuli
# Processing Record 38 of Set 6 | labuhan
# Processing Record 39 of Set 6 | tezu
# Processing Record 40 of Set 6 | hirara
# Processing Record 41 of Set 6 | altay
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | isangel
# Processing Record 44 of Set 6 | pangkalanbuun
# Processing Record 45 of Set 6 | bengkulu
# Processing Record 46 of Set 6 | usta muhammad
# Processing Record 47 of Set 6 | allingabro
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | aligudarz
# Processing Record 50 of Set 6 | carnarvon
# Processing Record 1 of Set 7 | rio gallegos
# Processing Record 2 of Set 7 | cap malheureux
# Processing Record 3 of Set 7 | karratha
# Processing Record 4 of Set 7 | ust-barguzin
# Processing Record 5 of Set 7 | kentwood
# Processing Record 6 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 7 | acarau
# Processing Record 8 of Set 7 | lebu
# Processing Record 9 of Set 7 | salalah
# Processing Record 10 of Set 7 | kavaratti
# Processing Record 11 of Set 7 | dandong
# Processing Record 12 of Set 7 | eyl
# Processing Record 13 of Set 7 | wonthaggi
# Processing Record 14 of Set 7 | gayny
# Processing Record 15 of Set 7 | dromolaxia
# Processing Record 16 of Set 7 | monterrey
# Processing Record 17 of Set 7 | saint-georges
# Processing Record 18 of Set 7 | atar
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | taywarah
# Processing Record 21 of Set 7 | sarankhola
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | bentiu
# Processing Record 24 of Set 7 | espoo
# Processing Record 25 of Set 7 | imbituba
# Processing Record 26 of Set 7 | kot isa khan
# Processing Record 27 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 7 | bataipora
# Processing Record 29 of Set 7 | port hedland
# Processing Record 30 of Set 7 | mogadishu
# Processing Record 31 of Set 7 | saint-ambroise
# Processing Record 32 of Set 7 | samarai
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | half moon bay
# Processing Record 35 of Set 7 | janoshalma
# Processing Record 36 of Set 7 | hearst
# Processing Record 37 of Set 7 | gerede
# Processing Record 38 of Set 7 | penzance
# Processing Record 39 of Set 7 | tarauaca
# Processing Record 40 of Set 7 | melfi
# Processing Record 41 of Set 7 | esperance
# Processing Record 42 of Set 7 | nizhniy ingash
# Processing Record 43 of Set 7 | altamira
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | ostersund
# Processing Record 46 of Set 7 | nouadhibou
# Processing Record 47 of Set 7 | sola
# Processing Record 48 of Set 7 | san vicente
# Processing Record 49 of Set 7 | ivangorod
# Processing Record 50 of Set 7 | vysokogornyy
# Processing Record 1 of Set 8 | nelson bay
# Processing Record 2 of Set 8 | portland
# Processing Record 3 of Set 8 | play cu
# City not found. Skipping...
# Processing Record 4 of Set 8 | fairbanks
# Processing Record 5 of Set 8 | corrales
# Processing Record 6 of Set 8 | dosso
# Processing Record 7 of Set 8 | bonavista
# Processing Record 8 of Set 8 | sainte-rose
# Processing Record 9 of Set 8 | sandwick
# Processing Record 10 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 8 | warrnambool
# Processing Record 12 of Set 8 | porto novo
# Processing Record 13 of Set 8 | sioux lookout
# Processing Record 14 of Set 8 | kahului
# Processing Record 15 of Set 8 | hendrina
# Processing Record 16 of Set 8 | nanortalik
# Processing Record 17 of Set 8 | tabou
# Processing Record 18 of Set 8 | slave lake
# Processing Record 19 of Set 8 | maloh
# Processing Record 20 of Set 8 | arman
# Processing Record 21 of Set 8 | moose factory
# Processing Record 22 of Set 8 | qasigiannguit
# Processing Record 23 of Set 8 | chicama
# Processing Record 24 of Set 8 | kattivakkam
# Processing Record 25 of Set 8 | san jose
# Processing Record 26 of Set 8 | asau
# Processing Record 27 of Set 8 | paamiut
# Processing Record 28 of Set 8 | khandyga
# Processing Record 29 of Set 8 | sabinopolis
# Processing Record 30 of Set 8 | high level
# Processing Record 31 of Set 8 | longyearbyen
# Processing Record 32 of Set 8 | buraydah
# Processing Record 33 of Set 8 | kasane
# Processing Record 34 of Set 8 | dori
# Processing Record 35 of Set 8 | santa cruz del sur
# Processing Record 36 of Set 8 | tutoia
# Processing Record 37 of Set 8 | kanigoro
# Processing Record 38 of Set 8 | mfou
# Processing Record 39 of Set 8 | itarema
# Processing Record 40 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 8 | araceli
# Processing Record 42 of Set 8 | williamsburg
# Processing Record 43 of Set 8 | luderitz
# Processing Record 44 of Set 8 | santa cruz
# Processing Record 45 of Set 8 | lambarene
# Processing Record 46 of Set 8 | cockburn town
# Processing Record 47 of Set 8 | quelimane
# Processing Record 48 of Set 8 | honningsvag
# Processing Record 49 of Set 8 | pareora
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | imeni babushkina
# Processing Record 2 of Set 9 | zhangye
# Processing Record 3 of Set 9 | seoul
# Processing Record 4 of Set 9 | tiznit
# Processing Record 5 of Set 9 | krasnyy chikoy
# Processing Record 6 of Set 9 | jieshi
# Processing Record 7 of Set 9 | pangnirtung
# Processing Record 8 of Set 9 | bandundu
# Processing Record 9 of Set 9 | sorland
# Processing Record 10 of Set 9 | kathmandu
# Processing Record 11 of Set 9 | kristiinankaupunki
# Processing Record 12 of Set 9 | okhotsk
# Processing Record 13 of Set 9 | le port
# Processing Record 14 of Set 9 | santa vitoria do palmar
# Processing Record 15 of Set 9 | college
# Processing Record 16 of Set 9 | svetlogorsk
# Processing Record 17 of Set 9 | saint-junien
# Processing Record 18 of Set 9 | kieta
# Processing Record 19 of Set 9 | kindersley
# Processing Record 20 of Set 9 | chagoda
# Processing Record 21 of Set 9 | cantaura
# Processing Record 22 of Set 9 | sile
# Processing Record 23 of Set 9 | pauini
# Processing Record 24 of Set 9 | severo-kurilsk
# Processing Record 25 of Set 9 | abu zabad
# Processing Record 26 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 9 | rocha
# Processing Record 28 of Set 9 | mangrol
# Processing Record 29 of Set 9 | la ronge
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | tigre
# Processing Record 32 of Set 9 | naze
# Processing Record 33 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 34 of Set 9 | opuwo
# Processing Record 35 of Set 9 | mandalgovi
# Processing Record 36 of Set 9 | thaba nchu
# Processing Record 37 of Set 9 | bull savanna
# Processing Record 38 of Set 9 | ricardo palma
# Processing Record 39 of Set 9 | naliya
# Processing Record 40 of Set 9 | northam
# Processing Record 41 of Set 9 | xichang
# Processing Record 42 of Set 9 | calabozo
# Processing Record 43 of Set 9 | hofn
# Processing Record 44 of Set 9 | presidente olegario
# Processing Record 45 of Set 9 | dalbandin
# Processing Record 46 of Set 9 | sao miguel do araguaia
# Processing Record 47 of Set 9 | weston
# Processing Record 48 of Set 9 | khovu-aksy
# Processing Record 49 of Set 9 | ust-maya
# Processing Record 50 of Set 9 | nyurba
# Processing Record 1 of Set 10 | ojinaga
# Processing Record 2 of Set 10 | olinda
# Processing Record 3 of Set 10 | kokoda
# Processing Record 4 of Set 10 | nizhniy tsasuchey
# Processing Record 5 of Set 10 | ozu
# Processing Record 6 of Set 10 | touros
# Processing Record 7 of Set 10 | sobolevo
# Processing Record 8 of Set 10 | rio grande
# Processing Record 9 of Set 10 | poya
# Processing Record 10 of Set 10 | kloulklubed
# Processing Record 11 of Set 10 | shetpe
# Processing Record 12 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 10 | dolinsk
# Processing Record 14 of Set 10 | boa vista
# Processing Record 15 of Set 10 | tianpeng
# Processing Record 16 of Set 10 | bizhbulyak
# Processing Record 17 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 10 | inuvik
# Processing Record 19 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 10 | shengjin
# Processing Record 21 of Set 10 | hokitika
# Processing Record 22 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 10 | lagos
# Processing Record 24 of Set 10 | chipata
# Processing Record 25 of Set 10 | toora-khem
# Processing Record 26 of Set 10 | griffith
# Processing Record 27 of Set 10 | vardo
# Processing Record 28 of Set 10 | pelym
# Processing Record 29 of Set 10 | tual
# Processing Record 30 of Set 10 | tamiahua
# Processing Record 31 of Set 10 | barreirinha
# Processing Record 32 of Set 10 | saint anthony
# Processing Record 33 of Set 10 | barhi
# Processing Record 34 of Set 10 | kisoro
# Processing Record 35 of Set 10 | grindavik
# Processing Record 36 of Set 10 | tshela
# Processing Record 37 of Set 10 | sumbe
# Processing Record 38 of Set 10 | devarkonda
# Processing Record 39 of Set 10 | nakusp
# Processing Record 40 of Set 10 | bedele
# Processing Record 41 of Set 10 | atambua
# Processing Record 42 of Set 10 | emerald
# Processing Record 43 of Set 10 | zalantun
# Processing Record 44 of Set 10 | gat
# Processing Record 45 of Set 10 | rudnogorsk
# Processing Record 46 of Set 10 | santoshpur
# Processing Record 47 of Set 10 | cove
# Processing Record 48 of Set 10 | tateyama
# Processing Record 49 of Set 10 | palencia
# Processing Record 50 of Set 10 | kovrov
# Processing Record 1 of Set 11 | rudbar
# Processing Record 2 of Set 11 | gogrial
# Processing Record 3 of Set 11 | mackay
# Processing Record 4 of Set 11 | korla
# Processing Record 5 of Set 11 | pangody
# Processing Record 6 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 11 | mochumi
# Processing Record 8 of Set 11 | bay roberts
# Processing Record 9 of Set 11 | maceio
# Processing Record 10 of Set 11 | gao
# Processing Record 11 of Set 11 | yingkou
# Processing Record 12 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 13 of Set 11 | ogulin
# Processing Record 14 of Set 11 | tahta
# Processing Record 15 of Set 11 | leh
# Processing Record 16 of Set 11 | togur
# Processing Record 17 of Set 11 | nalut
# Processing Record 18 of Set 11 | tromso
# Processing Record 19 of Set 11 | washington
# Processing Record 20 of Set 11 | ixtapa
# Processing Record 21 of Set 11 | nahariyya
# Processing Record 22 of Set 11 | strezhevoy
# Processing Record 23 of Set 11 | livramento
# Processing Record 24 of Set 11 | ghanzi
# Processing Record 25 of Set 11 | bintulu
# Processing Record 26 of Set 11 | sao gabriel da cachoeira
# Processing Record 27 of Set 11 | leeton
# Processing Record 28 of Set 11 | vila franca do campo
# Processing Record 29 of Set 11 | chor
# Processing Record 30 of Set 11 | bria
# Processing Record 31 of Set 11 | matara
# Processing Record 32 of Set 11 | raudeberg
# Processing Record 33 of Set 11 | teguldet
# Processing Record 34 of Set 11 | omsukchan
# Processing Record 35 of Set 11 | macomer
# Processing Record 36 of Set 11 | ugoofaaru
# Processing Record 37 of Set 11 | along
# Processing Record 38 of Set 11 | oranjemund
# Processing Record 39 of Set 11 | linares
# Processing Record 40 of Set 11 | the valley
# Processing Record 41 of Set 11 | provost
# Processing Record 42 of Set 11 | hengshui
# Processing Record 43 of Set 11 | amapa
# Processing Record 44 of Set 11 | gravdal
# Processing Record 45 of Set 11 | natal
# Processing Record 46 of Set 11 | hami
# Processing Record 47 of Set 11 | aykhal
# Processing Record 48 of Set 11 | sao felix do xingu
# Processing Record 49 of Set 11 | mazagao
# Processing Record 50 of Set 11 | cherdakly
# Processing Record 1 of Set 12 | tarata
# Processing Record 2 of Set 12 | dunedin
# Processing Record 3 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 4 of Set 12 | khomeynishahr
# City not found. Skipping...
# Processing Record 5 of Set 12 | wa
# City not found. Skipping...
# Processing Record 6 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 7 of Set 12 | aklavik
# Processing Record 8 of Set 12 | gifford
# Processing Record 9 of Set 12 | shelburne
# Processing Record 10 of Set 12 | rexburg
# Processing Record 11 of Set 12 | leningradskiy
# Processing Record 12 of Set 12 | matalom
# Processing Record 13 of Set 12 | lere
# Processing Record 14 of Set 12 | anlu
# Processing Record 15 of Set 12 | dalvik
# Processing Record 16 of Set 12 | ostrovnoy
# Processing Record 17 of Set 12 | kiama
# Processing Record 18 of Set 12 | karpuninskiy
# City not found. Skipping...
# Processing Record 19 of Set 12 | westport
# Processing Record 20 of Set 12 | redmond
# Processing Record 21 of Set 12 | muros
# Processing Record 22 of Set 12 | mahibadhoo
# Processing Record 23 of Set 12 | pacific grove
# Processing Record 24 of Set 12 | abonnema
# Processing Record 25 of Set 12 | adrar
# Processing Record 26 of Set 12 | prince rupert
# Processing Record 27 of Set 12 | srisailam
# Processing Record 28 of Set 12 | presidente medici
# Processing Record 29 of Set 12 | kanniyakumari
# Processing Record 30 of Set 12 | key largo
# Processing Record 31 of Set 12 | marsa matruh
# Processing Record 32 of Set 12 | jurado
# Processing Record 33 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 12 | bajil
# Processing Record 35 of Set 12 | novyy urengoy
# Processing Record 36 of Set 12 | jacobabad
# Processing Record 37 of Set 12 | porto belo
# Processing Record 38 of Set 12 | gobabis
# Processing Record 39 of Set 12 | ambanja
# Processing Record 40 of Set 12 | elizabeth city
# Processing Record 41 of Set 12 | santa rosa
# Processing Record 42 of Set 12 | monrovia
# Processing Record 43 of Set 12 | gornyy
# Processing Record 44 of Set 12 | puerto narino
# Processing Record 45 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 12 | liverpool
# Processing Record 47 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 48 of Set 12 | dinard
# Processing Record 49 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 12 | vostok
# Processing Record 1 of Set 13 | eureka
# Processing Record 2 of Set 13 | seymchan
# Processing Record 3 of Set 13 | sao filipe
# Processing Record 4 of Set 13 | borogontsy
# Processing Record 5 of Set 13 | balaipungut
# Processing Record 6 of Set 13 | myszkow
# Processing Record 7 of Set 13 | parainen
# Processing Record 8 of Set 13 | ous
# Processing Record 9 of Set 13 | borsec
# Processing Record 10 of Set 13 | camacha
# Processing Record 11 of Set 13 | kwekwe
# Processing Record 12 of Set 13 | calabar
# Processing Record 13 of Set 13 | wanning
# Processing Record 14 of Set 13 | ust-kulom
# Processing Record 15 of Set 13 | ardakan
# Processing Record 16 of Set 13 | san policarpo
# Processing Record 17 of Set 13 | hamilton
# Processing Record 18 of Set 13 | alugan
# Processing Record 19 of Set 13 | neiafu
# Processing Record 20 of Set 13 | guerrero negro
# Processing Record 21 of Set 13 | timbiqui
# Processing Record 22 of Set 13 | moses lake
# Processing Record 23 of Set 13 | chandbali
# Processing Record 24 of Set 13 | egvekinot
# Processing Record 25 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 13 | shatsk
# Processing Record 27 of Set 13 | carroll
# Processing Record 28 of Set 13 | bageshwar
# Processing Record 29 of Set 13 | tura
# Processing Record 30 of Set 13 | khani
# Processing Record 31 of Set 13 | zhigansk
# Processing Record 32 of Set 13 | ahipara
# Processing Record 33 of Set 13 | west odessa
# Processing Record 34 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 35 of Set 13 | harlingen
# Processing Record 36 of Set 13 | bandrele
# Processing Record 37 of Set 13 | carballo
# Processing Record 38 of Set 13 | flagstaff
# Processing Record 39 of Set 13 | cayenne
# Processing Record 40 of Set 13 | a
# City not found. Skipping...
# Processing Record 41 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 13 | lucero
# Processing Record 43 of Set 13 | tourlaville
# Processing Record 44 of Set 13 | lubango
# Processing Record 45 of Set 13 | nijar
# Processing Record 46 of Set 13 | ketchikan
# Processing Record 47 of Set 13 | freeport
# Processing Record 48 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 13 | biltine
# Processing Record 50 of Set 13 | nyaunglebin
# Processing Record 1 of Set 14 | coahuayana
# Processing Record 2 of Set 14 | tignere
# Processing Record 3 of Set 14 | constitucion
# Processing Record 4 of Set 14 | turinskaya sloboda
# Processing Record 5 of Set 14 | cotonou
# Processing Record 6 of Set 14 | brae
# Processing Record 7 of Set 14 | yeppoon
# Processing Record 8 of Set 14 | chumikan
# Processing Record 9 of Set 14 | moryakovskiy zaton
# Processing Record 10 of Set 14 | alice springs
# Processing Record 11 of Set 14 | morris
# Processing Record 12 of Set 14 | diofior
# Processing Record 13 of Set 14 | kalangala
# Processing Record 14 of Set 14 | marfino
# Processing Record 15 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | tefe
# Processing Record 17 of Set 14 | plouzane
# Processing Record 18 of Set 14 | lima
# Processing Record 19 of Set 14 | verkhovazhye
# Processing Record 20 of Set 14 | naryan-mar
# Processing Record 21 of Set 14 | san quintin
# Processing Record 22 of Set 14 | broken hill
# Processing Record 23 of Set 14 | comodoro rivadavia
# Processing Record 24 of Set 14 | riyadh
# Processing Record 25 of Set 14 | palmer
# Processing Record 26 of Set 14 | laukaa
# Processing Record 27 of Set 14 | dansolihon
# City not found. Skipping...
# Processing Record 28 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 29 of Set 14 | tautira
# Processing Record 30 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 31 of Set 14 | tsogni
# Processing Record 32 of Set 14 | santa isabel
# Processing Record 33 of Set 14 | dasoguz
# Processing Record 34 of Set 14 | dukat
# Processing Record 35 of Set 14 | kozan
# Processing Record 36 of Set 14 | hammerfest
# Processing Record 37 of Set 14 | altamont
# Processing Record 38 of Set 14 | nanchong
# Processing Record 39 of Set 14 | san andres
# Processing Record 40 of Set 14 | pervomayskiy
# Processing Record 41 of Set 14 | kailua
# Processing Record 42 of Set 14 | haademeeste
# City not found. Skipping...
# Processing Record 43 of Set 14 | taoudenni
# Processing Record 44 of Set 14 | prestea
# Processing Record 45 of Set 14 | collie
# Processing Record 46 of Set 14 | lavrentiya
# Processing Record 47 of Set 14 | erenhot
# Processing Record 48 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 14 | santa maria da vitoria
# Processing Record 50 of Set 14 | hobyo
# Processing Record 1 of Set 15 | qurayyat
# Processing Record 2 of Set 15 | guantanamo
# Processing Record 3 of Set 15 | cascais
# Processing Record 4 of Set 15 | ornskoldsvik
# Processing Record 5 of Set 15 | asfi
# Processing Record 6 of Set 15 | salinopolis
# Processing Record 7 of Set 15 | dhidhdhoo
# Processing Record 8 of Set 15 | moskovskiy
# Processing Record 9 of Set 15 | walvis bay
# Processing Record 10 of Set 15 | moyale
# Processing Record 11 of Set 15 | qabis
# City not found. Skipping...
# Processing Record 12 of Set 15 | buala
# Processing Record 13 of Set 15 | valdivia
# Processing Record 14 of Set 15 | manjacaze
# Processing Record 15 of Set 15 | port hardy
# Processing Record 16 of Set 15 | paciran
# Processing Record 17 of Set 15 | saint-joseph
# Processing Record 18 of Set 15 | channel-port aux basques
# Processing Record 19 of Set 15 | muisne
# Processing Record 20 of Set 15 | riachao do jacuipe
# Processing Record 21 of Set 15 | axim
# Processing Record 22 of Set 15 | mnogovershinnyy
# Processing Record 23 of Set 15 | mayskiy
# Processing Record 24 of Set 15 | moranbah
# Processing Record 25 of Set 15 | tete
# Processing Record 26 of Set 15 | harper
# Processing Record 27 of Set 15 | copiapo
# Processing Record 28 of Set 15 | beremend
# Processing Record 29 of Set 15 | ryotsu
# Processing Record 30 of Set 15 | lofthus
# Processing Record 31 of Set 15 | bemban
# Processing Record 32 of Set 15 | ternate
# Processing Record 33 of Set 15 | lubao
# Processing Record 34 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 15 | guayaramerin
# Processing Record 36 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 15 | severo-yeniseyskiy
# Processing Record 38 of Set 15 | damietta
# Processing Record 39 of Set 15 | turayf
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 679

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Butaritari   3.07  172.79     81.30        75          70       10.27
# 1  Tuktoyaktuk  69.45 -133.04     -0.40        84          20       11.41
# 2    Jamestown  42.10  -79.24     36.00        86          90       13.58
# 3     Manicore  -5.81  -61.30     89.71        60         100        1.25
# 4       Safaga  26.73   33.94     71.60        46           0        3.36
# 5      Ushuaia -54.80  -68.30     46.40        81          75       11.41
# 6    Hithadhoo  -0.60   73.08     82.24        75          72        9.01
# 7       Taltal -25.40  -70.48     67.19        58          93       10.92
# 8    Pringsewu  -5.36  104.97     73.99        92         100        3.00
# 9        Bluff -46.60  168.33     48.00        89         100        1.99
#
#        Current Description Country                 Date
# 0            broken clouds      KI  2020-11-23 17:19:00
# 1               few clouds      CA  2020-11-23 17:19:00
# 2                     mist      US  2020-11-23 17:16:31
# 3               light rain      BR  2020-11-23 17:19:00
# 4                clear sky      EG  2020-11-23 17:19:00
# 5  light intensity drizzle      AR  2020-11-23 17:19:01
# 6            broken clouds      MV  2020-11-23 17:19:01
# 7          overcast clouds      CL  2020-11-23 17:19:01
# 8          overcast clouds      ID  2020-11-23 17:19:01
# 9          overcast clouds      NZ  2020-11-23 17:19:01

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0   Butaritari      KI  2020-11-23 17:19:00   3.07  172.79     81.30
# 1  Tuktoyaktuk      CA  2020-11-23 17:19:00  69.45 -133.04     -0.40
# 2    Jamestown      US  2020-11-23 17:16:31  42.10  -79.24     36.00
# 3     Manicore      BR  2020-11-23 17:19:00  -5.81  -61.30     89.71
# 4       Safaga      EG  2020-11-23 17:19:00  26.73   33.94     71.60
# 5      Ushuaia      AR  2020-11-23 17:19:01 -54.80  -68.30     46.40
# 6    Hithadhoo      MV  2020-11-23 17:19:01  -0.60   73.08     82.24
# 7       Taltal      CL  2020-11-23 17:19:01 -25.40  -70.48     67.19
# 8    Pringsewu      ID  2020-11-23 17:19:01  -5.36  104.97     73.99
# 9        Bluff      NZ  2020-11-23 17:19:01 -46.60  168.33     48.00
#
#    Humidity  Cloudiness  Wind Speed      Current Description
# 0        75          70       10.27            broken clouds
# 1        84          20       11.41               few clouds
# 2        86          90       13.58                     mist
# 3        60         100        1.25               light rain
# 4        46           0        3.36                clear sky
# 5        81          75       11.41  light intensity drizzle
# 6        75          72        9.01            broken clouds
# 7        58          93       10.92          overcast clouds
# 8        92         100        3.00          overcast clouds
# 9        89         100        1.99          overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
